# %% [markdown]
# # Build AML Pipeline with azureml modules
#
# In this tutorial you will learn how to work with Azure ML module:
#
# 1. Setup enrivonment - install module CLI and module/pipeline SDK
# 2. Register a few sample modules into your aml workspace using CLI
# 3. Use module/pipeline SDK to create a pipeline with modules registered in step 2
#
# ## Prerequisite
# * Install Azure CLI, please follow [the Azure CLI installation instructions](https://docs.microsoft.com/en-us/cli/azure/install-azure-cli?view=azure-cli-latest) to install.

# %% [markdown]
# ## Setup environment
# * Install Azure CLI AML extension which includes the _module_ command group
# * Install Azure ML SDK including the APIs to work with _module_ and _pipeline_

# %%
# Uninstall azure-cli-ml (the `az ml` commands)
# !az extension remove -n azure-cli-ml 

# Install local version of azure-cli-ml (which includes `az ml module` commands)
# !az extension add --source https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/13766063/azure_cli_ml-0.1.0.13766063-py3-none-any.whl --pip-extra-index-urls https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/13766063 --yes
# Out:
# The extension azure-cli-ml is not installed.
#  - Downloading .. - Validating .. - Installing ..

# %%
# Verify the availability of `az ml module` commands
# !az ml module -h
# Out:
# Group
#     az ml module : Commands to manage modules.
#         Refer to https://aka.ms/moduledoc for details.
#
# Commands:
#     disable             : Disable a module.
#     download            : Download a module to a specified directory.
#     enable              : Enable a module.
#     list                : List modules in a workspace.
#     register            : Create or upgrade a module.
#     set-default-version : Set default version of a module.
#     show                : Show detail information of a module.
#     validate-spec       : Validate module spec file.
#
# For more specific examples, use: az find "az ml module"
#
# Please let us know how we are doing: https://aka.ms/clihats

# %%
# Install azureml-sdk with Pipeline, Module
# Important! After install succeed, need to restart kernel

# %config IPCompleter.greedyaz=True 
# !pip install --extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/14455084  azureml-pipeline-wrapper==0.1.0.14455084 --user --upgrade
# Out:
# █████████████| 1.2MB 417kB/s
# Requirement already satisfied, skipping upgrade: nbformat in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-pipeline-wrapper==0.1.0.14455084) (5.0.6)
# Collecting azureml-train-automl-client~=0.1.0.14455084
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/CLI-SDK-Runners-Validation/14455084/azureml_train_automl_client-0.1.0.14455084-py3-none-any.whl?sv=2018-03-28&sr=b&sig=jVMqCkLQwGv0lDtYCSw9Elr%2FJ10QKyEK0twmaWDXKUY%3D&st=2020-05-19T15%3A24%3A14Z&se=2021-05-19T15%3A24%3A14Z&sp=rl (79kB)
#      |████████████████████████████████| 81kB 6.7MB/s
# Collecting azureml-train-core~=0.1.0.14455084
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/CLI-SDK-Runners-Validation/14455084/azureml_train_core-0.1.0.14455084-py3-none-any.whl?sv=2018-03-28&sr=b&sig=AdNGMkk3st0MzMmSgqQUyeaYE53YiZc41obIUOZgdHk%3D&st=2020-05-19T15%3A24%3A14Z&se=2021-05-19T15%3A24%3A14Z&sp=rl (8.6MB)
#      |████████████████████████████████| 8.6MB 437kB/s
# Requirement already satisfied, skipping upgrade: docker in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (4.2.0)
# Requirement already satisfied, skipping upgrade: pyopenssl in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (19.1.0)
# Requirement already satisfied, skipping upgrade: pathspec in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.8.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.8.1)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.6.13)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource<9.0.0,>=1.2.1 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (8.0.1)
# Requirement already satisfied, skipping upgrade: azure-graphrbac>=0.40.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.61.1)
# Requirement already satisfied, skipping upgrade: SecretStorage in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (3.1.2)
# Requirement already satisfied, skipping upgrade: msrestazure>=0.4.33 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.6.3)
# Requirement already satisfied, skipping upgrade: pytz in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2020.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization>=0.40.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.60.0)
# Requirement already satisfied, skipping upgrade: ruamel.yaml<=0.15.89,>=0.15.35 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.15.89)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.5.1)
# Requirement already satisfied, skipping upgrade: azure-common>=1.1.12 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.1.25)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry>=2.0.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.8.0)
# Requirement already satisfied, skipping upgrade: adal>=1.2.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.2.3)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.25.9)
# Requirement already satisfied, skipping upgrade: PyJWT in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.7.1)
# Requirement already satisfied, skipping upgrade: jmespath in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.10.0)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.9.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage>=1.5.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (10.0.0)
# Requirement already satisfied, skipping upgrade: contextlib2 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.6.0.post1)
# Requirement already satisfied, skipping upgrade: jsonpickle in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.4.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault>=0.40.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.2.0)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.23.0)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.1 in /home/vsonline/.local/lib/python3.8/site-packages (from nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (4.3.3)
# Requirement already satisfied, skipping upgrade: jupyter-core in /home/vsonline/.local/lib/python3.8/site-packages (from nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (4.6.3)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /home/vsonline/.local/lib/python3.8/site-packages (from nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (3.0.1)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /home/vsonline/.local/lib/python3.8/site-packages (from nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (0.2.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep<1.4.5a,>=1.4.3a in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.4.3)
# Collecting azureml-automl-core~=0.1.0.14455084
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/CLI-SDK-Runners-Validation/14455084/azureml_automl_core-0.1.0.14455084-py3-none-any.whl?sv=2018-03-28&sr=b&sig=%2FFbt9B0PLHhqITZIZlSmf3sW7TYFs8yHoTIGCxKp9OE%3D&st=2020-05-19T15%3A24%3A14Z&se=2021-05-19T15%3A24%3A14Z&sp=rl (118kB)
#      |████████████████████████████████| 122kB 64.8MB/s
# Collecting azureml-telemetry~=0.1.0.14455084
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/CLI-SDK-Runners-Validation/14455084/azureml_telemetry-0.1.0.14455084-py3-none-any.whl?sv=2018-03-28&sr=b&sig=yjWoZh4wf8LrKTDcwXHrd9w7Q5KsVYUJcd04WTG6NHM%3D&st=2020-05-19T15%3A24%3A14Z&se=2021-05-19T15%3A24%3A14Z&sp=rl
# Requirement already satisfied, skipping upgrade: flake8<=3.7.9,>=3.1.0; python_version >= "3.6" in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-train-core~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (3.7.9)
# Collecting azureml-train-restclients-hyperdrive~=0.1.0.14455084
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/CLI-SDK-Runners-Validation/14455084/azureml_train_restclients_hyperdrive-0.1.0.14455084-py3-none-any.whl?sv=2018-03-28&sr=b&sig=sm5BOjgj%2FezDmnsou2Kv14QwdCKqL8C2vGqLB0thi8E%3D&st=2020-05-19T15%3A24%3A14Z&se=2021-05-19T15%3A24%3A14Z&sp=rl
# Requirement already satisfied, skipping upgrade: six>=1.4.0 in /home/vsonline/.local/lib/python3.8/site-packages (from docker->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.14.0)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /home/vsonline/.local/lib/python3.8/site-packages (from docker->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.57.0)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /home/vsonline/.local/lib/python3.8/site-packages (from msrest>=0.5.1->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.6.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/vsonline/.local/lib/python3.8/site-packages (from msrest>=0.5.1->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /home/vsonline/.local/lib/python3.8/site-packages (from msrest>=0.5.1->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.3.0)
# Requirement already satisfied, skipping upgrade: jeepney>=0.4.2 in /home/vsonline/.local/lib/python3.8/site-packages (from SecretStorage->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.4.3)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /home/vsonline/.local/lib/python3.8/site-packages (from ndg-httpsclient->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.4.8)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /home/vsonline/.local/lib/python3.8/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.14.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata in /home/vsonline/.local/lib/python3.8/site-packages (from jsonpickle->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.6.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/vsonline/.local/lib/python3.8/site-packages (from requests>=2.19.1->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.9)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/vsonline/.local/lib/python3.8/site-packages (from requests>=2.19.1->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (3.0.4)
# Requirement already satisfied, skipping upgrade: backports.weakref in /home/vsonline/.local/lib/python3.8/site-packages (from backports.tempfile->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.0.post1)
# Requirement already satisfied, skipping upgrade: decorator in /home/vsonline/.local/lib/python3.8/site-packages (from traitlets>=4.1->nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (4.4.2)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/vsonline/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (0.16.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/vsonline/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (19.3.0)
# Requirement already satisfied, skipping upgrade: setuptools in /opt/python/3.8.0/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->azureml-pipeline-wrapper==0.1.0.14455084) (42.0.2)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.1.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.4.1)
# Requirement already satisfied, skipping upgrade: dotnetcore2>=2.1.13 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.1.14)
# Requirement already satisfied, skipping upgrade: azure-identity<1.3.0,>=1.2.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.2.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<15.0.0,>=14.1.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (14.1.0)
# Requirement already satisfied, skipping upgrade: applicationinsights in /home/vsonline/.local/lib/python3.8/site-packages (from azureml-telemetry~=0.1.0.14455084->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.11.9)
# Requirement already satisfied, skipping upgrade: pyflakes<2.2.0,>=2.1.0 in /home/vsonline/.local/lib/python3.8/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.1.1)
# Requirement already satisfied, skipping upgrade: pycodestyle<2.6.0,>=2.5.0 in /home/vsonline/.local/lib/python3.8/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.5.0)
# Requirement already satisfied, skipping upgrade: entrypoints<0.4.0,>=0.3.0 in /home/vsonline/.local/lib/python3.8/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.3)
# Requirement already satisfied, skipping upgrade: mccabe<0.7.0,>=0.6.0 in /home/vsonline/.local/lib/python3.8/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.6.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /home/vsonline/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (3.1.0)
# Requirement already satisfied, skipping upgrade: pycparser in /home/vsonline/.local/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (2.20)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/vsonline/.local/lib/python3.8/site-packages (from importlib-metadata->jsonpickle->azureml-core~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (3.1.0)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /home/vsonline/.local/lib/python3.8/site-packages (from dotnetcore2>=2.1.13->azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.4.0)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.0.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.5.0)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.0.0 in /home/vsonline/.local/lib/python3.8/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.3.0)
# Requirement already satisfied, skipping upgrade: msal-extensions~=0.1.3 in /home/vsonline/.local/lib/python3.8/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (0.1.3)
# Requirement already satisfied, skipping upgrade: portalocker~=1.0 in /home/vsonline/.local/lib/python3.8/site-packages (from msal-extensions~=0.1.3->azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.4.5a,>=1.4.3a->azureml-train-automl-client~=0.1.0.14455084->azureml-pipeline-steps~=0.1.0.14455084->azureml-pipeline-wrapper==0.1.0.14455084) (1.7.0)
# Installing collected packages: azureml-core, azureml-pipeline-core, azureml-automl-core, azureml-telemetry, azureml-train-automl-client, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-pipeline-steps, azureml-pipeline-wrapper
#   Found existing installation: azureml-core 0.1.0.14253903
#     Uninstalling azureml-core-0.1.0.14253903:
#       Successfully uninstalled azureml-core-0.1.0.14253903
#   Found existing installation: azureml-pipeline-core 0.1.0.14253903
#     Uninstalling azureml-pipeline-core-0.1.0.14253903:
#       Successfully uninstalled azureml-pipeline-core-0.1.0.14253903
#   Found existing installation: azureml-automl-core 0.1.0.14253903
#     Uninstalling azureml-automl-core-0.1.0.14253903:
#       Successfully uninstalled azureml-automl-core-0.1.0.14253903
#   Found existing installation: azureml-telemetry 0.1.0.14253903
#     Uninstalling azureml-telemetry-0.1.0.14253903:
#       Successfully uninstalled azureml-telemetry-0.1.0.14253903
#   Found existing installation: azureml-train-automl-client 0.1.0.14253903
#     Uninstalling azureml-train-automl-client-0.1.0.14253903:
#       Successfully uninstalled azureml-train-automl-client-0.1.0.14253903
#   Found existing installation: azureml-train-restclients-hyperdrive 0.1.0.14253903
#     Uninstalling azureml-train-restclients-hyperdrive-0.1.0.14253903:
#       Successfully uninstalled azureml-train-restclients-hyperdrive-0.1.0.14253903
#   Found existing installation: azureml-train-core 0.1.0.14253903
#     Uninstalling azureml-train-core-0.1.0.14253903:
#       Successfully uninstalled azureml-train-core-0.1.0.14253903
#   Found existing installation: azureml-pipeline-steps 0.1.0.14253903
#     Uninstalling azureml-pipeline-steps-0.1.0.14253903:
#       Successfully uninstalled azureml-pipeline-steps-0.1.0.14253903
#   Found existing installation: azureml-pipeline-wrapper 0.1.0.14253903
#     Uninstalling azureml-pipeline-wrapper-0.1.0.14253903:
#       Successfully uninstalled azureml-pipeline-wrapper-0.1.0.14253903
# Successfully installed azureml-automl-core-0.1.0.14455084 azureml-core-0.1.0.14455084 azureml-pipeline-core-0.1.0.14455084 azureml-pipeline-steps-0.1.0.14455084 azureml-pipeline-wrapper-0.1.0.14455084 azureml-telemetry-0.1.0.14455084 azureml-train-automl-client-0.1.0.14455084 azureml-train-core-0.1.0.14455084 azureml-train-restclients-hyperdrive-0.1.0.14455084
# Cleaning up...
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Register AML Module
#
# You can manage AML module through [azure-cli-ml](https://aka.ms/moduledoc) or [ml.azure.com](https://ml.azure.com/). <br>
#
# Module could be registered from:
# - local path
# - public Github url
# - Azure DevOps build artifacts
#
# Azureml module support multiple module type:
# - Basic python module
# - Mpi module
# - Parallel run module
# - Hdi module (pending on backend support)

# %%
# you need to configure your ws information here

subscription_id = '74eccef0-4b8d-4f83-b5f9-fa100d155b22'
workspace_name = 'kubeflow_ws_1'
resource_group = 'kubeflow-demo'

# Specify available aml compute in workspace
pipeline_compute = "kubeflow-aks"

# %%
# Configure your aml workspace 

# !az login 
# !az account set -s $subscription_id 
# !az ml folder attach -w $workspace_name -g $resource_group
# Out:
# tId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "10a1cf3f-9a29-4c5d-aef4-0f6a234190af",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML V1 INT 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d128f140-94e6-4175-87a7-954b9d27db16",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Personal 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4f455bd0-f95a-4b7d-8d08-078611508e0b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML V1 Build 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e9b2ec51-5c94-4fa8-809a-dc1e695e4896",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Personal 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f8f8b81c-3ebd-427c-b3b7-ebb226c4eea2",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Stress 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4ee2639f-70ee-4e6f-99f6-b4361dbe4ce1",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MAML Production_20_2 WestCentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "74eccef0-4b8d-4f83-b5f9-fa100d155b22",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Build 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4e7b3094-d7f1-4973-8734-e82a24f1590e",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML V1 INT 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "95453742-57f9-49b0-9605-d2cf657da022",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna PROD - WestUS2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0d26e53d-f126-4051-83d6-75f1be8bedeb",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MAML Production_16 Australia",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a20c82c7-4497-4d44-952a-3105f790e26b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "PhillyExt",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "02742076-9634-42e2-953f-0134919bb62f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_AICore_AdsMPS_100469",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f9b96b36-1f5e-4021-8959-51527e26e6d3",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "CS-Platform-Dev-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "381b38e9-9840-4719-a5a0-61d9585e1e91",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AutoML Demo",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "121ed073-2274-4c26-8287-896e4afef998",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_BingAds_BI_100002",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "60d86a1d-43f9-4fef-9c37-871a3c085e42",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "MatrixTest SubstrateGPU",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "006c8ad5-cb8a-4900-bb78-2115733f9d0c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_C&E_DPG_Azure ML_100293",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0ee09efa-4037-4147-b986-296082064383",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Microsoft Azure Internal Consumption",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9ec1d932-0f3f-486c-acc6-e7d78b358f9b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "TScience",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "46da6261-2167-4e71-8b0d-f4a45215ce61",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "GCR Prod Internet First",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "41c6e824-0f66-4076-81dd-f751c70a140b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "rfernand-ML_research_and_tools",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "710e04b9-9155-4f01-aa8e-52848f055ad2",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "MSRLabs Azure ML Pilot",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3d75862d-3a43-450d-8046-895947d5abfa",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Speech Infrastructure",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d20432c3-8203-4c39-865a-7c6c2fb1ffd2",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSR AI - MLO",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7c469e39-c3bc-4752-a3f1-7447c5aecfa8",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Customer 360 DevTest 001",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8cff5d56-95fb-4a74-ab9d-079edb45313e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "cdc5aeea-15c5-4db6-b079-fcadd2505dc2"
#       }
#     ],
#     "name": "Skype-NetEM-PROD",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7fd08dcc-a653-4b0f-8f8c-4dac889fdda4",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Code generate Test and Infra",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "27b2ee0a-4093-4253-95b5-c595487ad66f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "EvanBaCore",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eec2de82-6ab2-4a84-ae5f-57e9a10bf661",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ServicesPortfolio MCS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d21a0e9f-5e29-4b39-8ba5-0e189bc5fe2d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Edge DevTools Client",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "68737473-7c94-452c-b726-6ba2740fc6a1",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_IPG_Shared Data_100415",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1665c0dd-2edd-4c8b-af89-aabe2bd8eef5",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "cdc5aeea-15c5-4db6-b079-fcadd2505dc2"
#       }
#     ],
#     "name": "ADL_Extended_E+D_M365Core_GDPR",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "26f44790-d972-4071-91cc-95dfa361f566",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "CosmosConvergenceTestStore",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "5238125b-91e1-435e-b9fb-20b537d6df4d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_IPG_Data Mining_100021",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a722c841-e36d-4438-8998-f7f34f430adb",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Ibiza Extensions - Dev Environment",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "59575035-46ba-4b83-8025-0cb076c7c097",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "STCA-Segment Intelligence",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "6ad709f4-8451-47eb-b4aa-24733abf60e4",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "MSR AI Engineering General Purpose",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "63b4eb97-4823-4ffb-8eca-1b60f3d697f0",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AI Platform GPU 26 - Bing Ads Philly to AML",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b01d3783-f526-474f-9c46-19c1080fdb7b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Xap - Production Tools",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "04150703-feca-4f63-a3a5-be940713f2ea",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_AICore_AdsMPS_100461",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "52a442a2-31e9-42f9-8e3e-4b27dbf82673",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Core-ES-WorkManagement",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ef3a6d54-2b53-49f6-b905-7c7ec83487a6",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Visual Studio Enterprise",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b3f93e12-32e4-4d37-ab91-f63280a05b15",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "STCA-VM-003",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a947bb9f-f570-40a9-82cc-2fdd09f1553a",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Bing Ads AML Pilot",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "03edb68d-358f-4a6e-91bb-cb547236069c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_AICore_AdsMPS_100471",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ee85ed72-2b26-48f6-a0e8-cb5bcf98fbd9",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Subscription-1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "jietong@microsoft.com",
#       "type": "user"
#     }
#   }
# ]
# {
#   "Experiment name": "hello-aml-modules",
#   "Project path": "/home/vsonline/workspace/hello-aml-modules",
#   "Resource group": "kubeflow-demo",
#   "Subscription id": "74eccef0-4b8d-4f83-b5f9-fa100d155b22",
#   "Workspace name": "kubeflow_ws_1"
# }

# %%
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/sar_train.yaml --set-as-default-version
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/stratified_splitter.yaml --set-as-default-version
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/sar_score.yaml --set-as-default-version
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/recall_at_k.yaml --set-as-default-version
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/map.yaml --set-as-default-version
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/ndcg.yaml --set-as-default-version
# !az ml module register --spec-file=https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/precision_at_k.yaml --set-as-default-version
# Out:
# {
#   "contact": null,
#   "defaultVersion": "1.1.1",
#   "description": "SAR Train from Recommenders repo: https://github.com/Microsoft/Recommenders.",
#   "helpDocument": null,
#   "lastUpdatedOn": "2020-05-19T23:53:08.3602071Z",
#   "name": "SAR Training",
#   "namespace": "microsoft.com/cat",
#   "registeredBy": "Jie Tong",
#   "registeredOn": "2020-04-16T08:01:19.6800299Z",
#   "status": "Active",
#   "tags": [
#     "Recommenders"
#   ],
#   "version": "1.1.1",
#   "versions": [
#     "1.1.0",
#     "1.1.1"
#   ],
#   "yamlLink": "https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/sar_train.yaml"
# }
# Version 1.1.1 has already exist in module Stratified Splitter (namespace: microsoft.com/cat)
# {}
# Azure-cli-ml Version: 0.1.0.13766063
#
# Learn more about optional inputs: https://aka.ms/azureml-module-optional-inputs
# {
#   "contact": null,
#   "defaultVersion": "1.1.1",
#   "description": "Recall at K metric from Recommenders repo: https://github.com/Microsoft/Recommenders.",
#   "helpDocument": null,
#   "lastUpdatedOn": "2020-05-19T23:53:35.971426Z",
#   "name": "Recall at K",
#   "namespace": "microsoft.com/cat",
#   "registeredBy": "Jie Tong",
#   "registeredOn": "2020-04-16T07:55:50.4876092Z",
#   "status": "Active",
#   "tags": [
#     "Recommenders",
#     "Metrics"
#   ],
#   "version": "1.1.1",
#   "versions": [
#     "1.1.0",
#     "1.1.1"
#   ],
#   "yamlLink": "https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/recall_at_k.yaml"
# }
# {
#   "contact": null,
#   "defaultVersion": "1.1.1",
#   "description": "Mean Average Precision at K metric from Recommenders repo: https://github.com/Microsoft/Recommenders.",
#   "helpDocument": null,
#   "lastUpdatedOn": "2020-05-19T23:53:42.708205Z",
#   "name": "MAP",
#   "namespace": "microsoft.com/cat",
#   "registeredBy": "Jie Tong",
#   "registeredOn": "2020-04-16T07:44:53.6714349Z",
#   "status": "Active",
#   "tags": [
#     "Recommenders",
#     "Metrics"
#   ],
#   "version": "1.1.1",
#   "versions": [
#     "1.1.0",
#     "1.1.1"
#   ],
#   "yamlLink": "https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/map.yaml"
# }
# {
#   "contact": null,
#   "defaultVersion": "1.1.1",
#   "description": "Normalized Discounted Cumulative Gain (nDCG) at K metric from Recommenders repo: https://github.com/Microsoft/Recommenders.",
#   "helpDocument": null,
#   "lastUpdatedOn": "2020-05-19T23:53:52.1707537Z",
#   "name": "nDCG",
#   "namespace": "microsoft.com/cat",
#   "registeredBy": "Jie Tong",
#   "registeredOn": "2020-04-16T07:50:21.1404236Z",
#   "status": "Active",
#   "tags": [
#     "Recommenders",
#     "Metrics"
#   ],
#   "version": "1.1.1",
#   "versions": [
#     "1.1.0",
#     "1.1.1"
#   ],
#   "yamlLink": "https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/ndcg.yaml"
# }
# {
#   "contact": null,
#   "defaultVersion": "1.1.1",
#   "description": "Precision at K metric from Recommenders repo: https://github.com/Microsoft/Recommenders.",
#   "helpDocument": null,
#   "lastUpdatedOn": "2020-05-19T23:53:59.2081271Z",
#   "name": "Precision at K",
#   "namespace": "microsoft.com/cat",
#   "registeredBy": "Jie Tong",
#   "registeredOn": "2020-04-16T07:52:32.8480128Z",
#   "status": "Active",
#   "tags": [
#     "Recommenders",
#     "Metrics"
#   ],
#   "version": "1.1.1",
#   "versions": [
#     "1.1.0",
#     "1.1.1"
#   ],
#   "yamlLink": "https://github.com/microsoft/recommenders/blob/master/reco_utils/azureml/azureml_designer_modules/module_specs/precision_at_k.yaml"
# }

# %% [markdown]
# ## Create pipeline
# You can build pipeline through SDK experience, or drag-n-drop way through [Designer](https://ml.azure.com/visualinterface?wsid=/subscriptions/74eccef0-4b8d-4f83-b5f9-fa100d155b22/resourcegroups/kubeflow-demo/workspaces/kubeflow_ws_1&flight=cm,nml,newGraphDetail,newGraphAuthoring,all&tid=72f988bf-86f1-41af-91ab-2d7cd011db47) in workspace portal
#
# The new SDK:
# * Symplified the syntax to provide consistent experience with drag-n-drop
# * Support intellisense and docstring, free you to work with dict all the time
# * Support creating a pipeline with unpublished module

# %%
from azureml.core import Workspace, Run, Dataset, Datastore
from azureml.pipeline.wrapper import Pipeline, Module, dsl

ws = Workspace.get(name=workspace_name, subscription_id=subscription_id, resource_group=resource_group)

# get modules
sar_split = Module.load(ws, namespace='microsoft.com/cat', name='Stratified Splitter')
sar_train = Module.load(ws, namespace='microsoft.com/cat', name='SAR Training')
sar_score = Module.load(ws, namespace='microsoft.com/cat', name='SAR Scoring')
sar_map = Module.load(ws, namespace='microsoft.com/cat', name='MAP')
sar_ndcg = Module.load(ws, namespace='microsoft.com/cat', name='nDCG')
sar_recall = Module.load(ws, namespace='microsoft.com/cat', name='Recall at K')
sar_precision = Module.load(ws, namespace='microsoft.com/cat', name='Precision at K')

# get dataset
data_name = 'Movie_Ratings'

if data_name not in ws.datasets:
    global_datastore = Datastore(ws, name="azureml_globaldatasets")
    movie_ratings_data = Dataset.File.from_files(global_datastore.path('GenericCSV/Movie_Ratings')).register(workspace=ws, name='Movie_Ratings', description='movie rating data')
    print('Registerd')

movie_ratings_data = ws.datasets[data_name]
print('Training dataset found in workspace')
# Out:
# Registerd
# Training dataset found in workspace

# %%
#define a sub pipeline
@dsl.pipeline(name = 'recommender-evaluation', 
              description = 'recall, precision, ndcg, map')
def sar_eval(user_col, item_col, rating_col, precision_col, method, top_n, threshold, test_input, score_input):   
    recall = sar_recall(user_column=user_col, item_column=item_col, rating_column=rating_col, prediction_column=precision_col,
                       relevancy_method=method, top_k=top_n, threshold=threshold,
                       rating_true=test_input,
                       rating_pred=score_input)
    
    map = sar_map(user_column=user_col, item_column=item_col, rating_column=rating_col, prediction_column=precision_col,
                 relevancy_method=method, top_k=top_n, threshold=threshold,
                 rating_true=test_input,
                 rating_pred=score_input)
    
    precision = sar_precision(user_column=user_col, item_column=item_col, rating_column=rating_col, prediction_column=precision_col,
                 relevancy_method=method, top_k=top_n, threshold=threshold,
                 rating_true=test_input,
                 rating_pred=score_input)
    
    ndcg = sar_ndcg(user_column=user_col, item_column=item_col, rating_column=rating_col, prediction_column=precision_col,
                 relevancy_method=method, top_k=top_n, threshold=threshold,
                 rating_true=test_input,
                 rating_pred=score_input)    
    
    return {'recall': recall.outputs.score, 'precision': precision.outputs.score, 'ndcg': ndcg.outputs.score, 'map': map.outputs.score}

# %%
#define a pipeline
@dsl.pipeline(name = 'recommender pipeline', 
              description = 'recommender pipeline with SAR algo',
              default_compute_target = pipeline_compute)
def sar_pipeline(top_n, threshold):
    split = sar_split(input_path=movie_ratings_data, 
                      ratio=0.75, seed=42, 
                      user_column='UserId', item_column='MovieId')
    
    train = sar_train(input_path=split.outputs.output_train_data, 
                      user_column='UserId', item_column='MovieId', rating_column='Rating', timestamp_column='Timestamp',
                      time_decay=False, normalize=False)
    
    
    score = sar_score(trained_model=train.outputs.output_model, dataset_to_score=split.outputs.output_test_data,
                     score_type='Item recommendation', ranking_metric='Rating', top_k=top_n, sort_top_k=True)
    
    eval = sar_eval('UserId', 'MovieId', 'Rating', 'prediction', 
                    'top_k', 10, 1.0, 
                    split.outputs.output_test_data, score.outputs.score_result)
    
    return {**eval.outputs}

pipeline = sar_pipeline(10, 1.0)

# %%
# validate pipeline and visualize the graph
pipeline.validate()
# Out:
#         <style>
#         #container_id_805f30cd-14f7-4ae9-a85e-24da104b957c svg.react-dag-editor-svg-container {
#             height: 800px;
#         }
#         </style>
#         <div id="container_id_805f30cd-14f7-4ae9-a85e-24da104b957c"></div>
#         <script>
#             window.render_container_id="container_id_805f30cd-14f7-4ae9-a85e-24da104b957c"
#             window.graph_json={"pipeline": {"name": "recommender pipeline", "parameters": {"top_n": {"type": "int", "default": 10}}, "data_references": {"input_path": {"dataset_id": "8be84af9-f88c-4a0e-990f-514e5485f2f4"}}, "steps": {"microsoft.com/cat://Stratified Splitter": {"module": {"id": "62965364-c036-4584-8b6d-c449c89c3820", "version": "1.2.0"}, "parameters": {"ServingEntry": "", "MLCComputeType": "AmlCompute", "PrepareEnvironment": "true", "Script": "reco_utils/azureml/azureml_designer_modules/entries/stratified_splitter_entry.py", "Framework": "Python", "InterpreterPath": "python", "UserManagedDependencies": false, "CondaDependencies": "{\"name\": \"Recommenders_module_environment\", \"channels\": [\"defaults\"], \"dependencies\": [\"python=3.7\", {\"pip\": [\"pandas>=0.23.4,<1.0.0\", \"pyarrow>=0.13.0\", \"azureml-core==1.0.85.*\", \"azureml-designer-core==0.0.26.*\", \"azureml-dataprep==1.4.3\", \"joblib==0.14.0\", \"scikit-learn==0.20.3\"]}]}", "DockerEnabled": "true", "BaseDockerImage": "mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04", "GpuSupport": "false", "HistoryEnabled": "true", "Ratio": 0.75, "User column": "UserId", "Item column": "MovieId", "Seed": 42, "TargetType": "mlc", "RequireGpu": "False", "HasServingEntry": "False", "PassthroughServingMode": "False", "ModuleUI": "Default", "ModuleVersion": "1.2.0", "Owner": null}, "inputs": {"Input_path": {"source": "input_path", "type": "mount", "overwrite": false}}, "outputs": {"Output_train_data": {"destination": "Output_train_data9510e449", "type": "mount", "datastore": "workspaceblobstore"}, "Output_test_data": {"destination": "Output_test_data9510e449", "type": "mount", "datastore": "workspaceblobstore"}}, "arguments": ["USE_STRUCTURED_ARGUMENTS"], "compute": "cpu-cluster", "validate": {"error": [], "module_id": "62965364-c036-4584-8b6d-c449c89c3820", "module_name": "Stratified Splitter", "module_version": "1.2.0"}}, "microsoft.com/cat://SAR Training": {"module": {"id": "cb075d27-aac4-4999-9298-0dad2eaeb23e", "version": "1.1.1"}, "parameters": {"ServingEntry": "", "MLCComputeType": "AmlCompute", "PrepareEnvironment": "true", "GpuSupport": "false", "HistoryEnabled": "true", "Framework": "Python", "Script": "reco_utils/azureml/azureml_designer_modules/entries/train_sar_entry.py", "MaxRunDurationSeconds": "", "InterpreterPath": "python", "UserManagedDependencies": false, "CondaDependencies": "{\"name\": \"Recommenders_module_environment\", \"channels\": [\"defaults\"], \"dependencies\": [\"python=3.7\", {\"pip\": [\"pandas>=0.23.4,<1.0.0\", \"pyarrow>=0.13.0\", \"azureml-defaults\", \"azureml-designer-core\", \"joblib==0.14.0\", \"scikit-learn==0.20.3\"]}]}", "DockerEnabled": "true", "BaseDockerImage": "mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04", "User column": "UserId", "Item column": "MovieId", "Rating column": "Rating", "Timestamp column": "Timestamp", "Normalize": false, "Time decay": false, "TargetType": "mlc", "RequireGpu": "False", "HasServingEntry": "False", "PassthroughServingMode": "False", "ModuleUI": "Default", "ModuleVersion": "1.1.1", "Owner": ""}, "inputs": {"Input_path": {"source": "Output_train_data9510e449", "type": "mount"}}, "outputs": {"Output_model": {"destination": "Output_model8f825843", "type": "mount", "datastore": "workspaceblobstore"}}, "arguments": ["USE_STRUCTURED_ARGUMENTS"], "compute": "cpu-cluster", "validate": {"error": [], "module_id": "cb075d27-aac4-4999-9298-0dad2eaeb23e", "module_name": "SAR Training", "module_version": "1.1.1"}}, "microsoft.com/cat://SAR Scoring": {"module": {"id": "ee84dd5c-15fd-4c52-8a2f-1b5c3b2e2be2", "version": "1.1.0"}, "parameters": {"ServingEntry": "", "MLCComputeType": "AmlCompute", "PrepareEnvironment": "true", "Script": "reco_utils/azureml/azureml_designer_modules/entries/score_sar_entry.py", "Framework": "Python", "InterpreterPath": "python", "UserManagedDependencies": false, "CondaDependencies": "{\"name\": \"Recommenders_module_environment\", \"channels\": [\"defaults ...
# {'result': 'validation passed', 'errors': []}

# %%
# save as a draft
pipeline.save(experiment_name = 'recommender-pipeline-sar', id = '767f99ef-9d0d-4518-b9aa-9faf0170b954')
# Out:
# Pipeline(Name: recommender pipeline,
# Id: 767f99ef-9d0d-4518-b9aa-9faf0170b954,
# Tags: {},
# Properties: {},
# Last Submitted Pipeline Run Id: None)

# %%
run = pipeline.submit(experiment_name = 'recommender-pipeline-sar')
run.wait_for_completion()
# Out:
# {'runId': 'f7a18440-3279-4052-a154-1bd70bac6dd3',
#  'status': 'Completed',
#  'startTimeUtc': '2020-05-19T23:59:33.444907Z',
#  'endTimeUtc': '2020-05-20T00:14:43.132142Z',
#  'properties': {'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Designer',
#   'runType': 'HTTP',
#   'azureml.parameters': '{"top_n":"10"}'},
#  'inputDatasets': [],
#  'logFiles': {'azureml-logs/kfcloud.txt': 'https://kubeflowws17354384724.blob.core.windows.net/azureml/ExperimentRun/dcid.f7a18440-3279-4052-a154-1bd70bac6dd3/azureml-logs/kfcloud.txt?sv=2019-02-02&sr=b&sig=sYkddNjx2wXaxkOpAqJD0Hrym0rk7TyNFXiU1SbCLgI%3D&st=2020-05-20T00%3A04%3A45Z&se=2020-05-20T08%3A14%3A45Z&sp=r',
#   'azureml-logs/kubeflow.yaml': 'https://kubeflowws17354384724.blob.core.windows.net/azureml/ExperimentRun/dcid.f7a18440-3279-4052-a154-1bd70bac6dd3/azureml-logs/kubeflow.yaml?sv=2019-02-02&sr=b&sig=kdxgrdrMtIH3%2FL4uHT%2BfbfFEoAgd%2FdbbzoxEoT82xtM%3D&st=2020-05-20T00%3A04%3A45Z&se=2020-05-20T08%3A14%3A45Z&sp=r',
#   'azureml-logs/manifest.json': 'https://kubeflowws17354384724.blob.core.windows.net/azureml/ExperimentRun/dcid.f7a18440-3279-4052-a154-1bd70bac6dd3/azureml-logs/manifest.json?sv=2019-02-02&sr=b&sig=On9Bj1CzTjX9DopRchQIgNQcUsRsQ7%2ByZiKEnxPtCfM%3D&st=2020-05-20T00%3A04%3A45Z&se=2020-05-20T08%3A14%3A45Z&sp=r'}}
